# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
ineuron_courses_url = "https://ineuron.ai/courses"

# %%
ineuron_courses_url
# Out:
# 'https://ineuron.ai/courses'

# %% [raw]
# By the above variable, We shuld able to reach the ineuron courses page.
# Now, we are going to reach the particular url through python code.

# %%
uClient = uReq(ineuron_courses_url)

# %%
uClient

# %%
ineuronCoursesPage = uClient.read()

# %%
ineuronCoursesPage
# It will return the right click + view page source of the page
# Out:
# b'<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><meta name="next-head-count" content="2"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.15.3/css/all.min.css" integrity="sha512-iBBXm8fW90+nuLcSKlbmrPcLa0OT92xO1BIsZ+ywDWZCvqsWgccV3gFoRBv0z+8dLJgyAHIhR35VZc2oM/gI1w==" crossorigin="anonymous"/><link rel="apple-touch-icon" sizes="180x180" href="/images/favicon/apple-touch-icon.png"/><link rel="icon" type="image/png" sizes="32x32" href="/images/favicon/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="/images/favicon/favicon-16x16.png"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/6.8.4/swiper-bundle.min.css"/><link rel="preload" href="/_next/static/css/4300158ae05fc67f.css" as="style"/><link rel="stylesheet" href="/_next/static/css/4300158ae05fc67f.css" data-n-g=""/><link rel="preload" href="/_next/static/css/2fec4b189947c1d9.css" as="style"/><
# ...

# %% [raw]
# For example, ineuronCoursesPage contains the list of the courses list.
# But I need to click the course name to redirect to course page. But course page contains the so much of links.
#
# Aftre clicking the course, it is going to open a new url.
#
# ineuronCoursesPage variable consists the whole information about the course list page, form that I only needs the urls of the courses to find out the course info.
# ineuronCoursesPage variable consists of all information and in the unreadable form.

# %%
uClient.close()

# %%
ineuron_courses_html = bs(ineuronCoursesPage, "html.parser")
# bs is a alias of beautiful soap
# It is responsible to find the HTML tags
# This will readable

# %%
ineuron_courses_html
# Out:
# <!DOCTYPE html>
# ...

# %% [raw]
# Our focus is to find the urls from that page
#
# In the course list page, you can see every course listed in the div tag with the class Course_course-card__f7WLr Course_card__rBLhD card
# So, we are going to find the div with the particular class name.

# %%
ineuron_courses_html.findAll("div", {"class": "TopCategoryList_top-categories__cTGOc"})
# Out:
# []

# %%
# Out:
# []
